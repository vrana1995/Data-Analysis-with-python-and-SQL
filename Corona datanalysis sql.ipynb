# %%
import pandas as pd
import sqlalchemy as sq

# %%
con = sq.create_engine('mysql+pymysql://root:user@localhost/my_database')

# %%
df1= pd.read_csv('C:\\Users\\vishal rana\\Downloads\\Covid deaths.csv')
df2= pd.read_csv('C:\\Users\\vishal rana\\Downloads\\Covid Vaccinations.csv')

# %%
df1.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  24-02-2020          5.0        5.0
# 1      AFG      Asia  Afghanistan  25-02-2020          5.0        0.0
# 2      AFG      Asia  Afghanistan  26-02-2020          5.0        0.0
# 3      AFG      Asia  Afghanistan  27-02-2020          5.0        0.0
# 4      AFG      Asia  Afghanistan  28-02-2020          5.0        0.0
#
#    population  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0  39835428.0                 NaN           NaN         NaN  ...
# 1  39835428.0                 NaN           NaN         NaN  ...
# 2  39835428.0                 NaN           NaN         NaN  ...
# 3  39835428.0                 NaN           NaN         NaN  ...
# 4  39835428.0                 NaN           NaN         NaN  ...
#
#    new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# 0                              NaN                NaN           NaN
# ...

# %%
df2.head()
# Out:
#   iso_code continent     location        date  total_tests  \
# 0      AFG      Asia  Afghanistan  24-02-2020          NaN
# 1      AFG      Asia  Afghanistan  25-02-2020          NaN
# 2      AFG      Asia  Afghanistan  26-02-2020          NaN
# 3      AFG      Asia  Afghanistan  27-02-2020          NaN
# 4      AFG      Asia  Afghanistan  28-02-2020          NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  positive_rate  ...  female_smokers  \
# 0                              NaN            NaN  ...             NaN
# ...

# %%
df1.to_sql(name= 'covid_deaths',con = con)

# %%
df2.to_sql(name= 'covid_vac',con = con)

# %%
sql= '''
select *
from covid_deaths
limit 5'''
df1.sql= pd.read_sql_query(sql,con)
df1.sql
# Out:
#    index iso_code continent     location        date  total_cases  new_cases  \
# 0      0      AFG      Asia  Afghanistan  24-02-2020          5.0        5.0
# 1      1      AFG      Asia  Afghanistan  25-02-2020          5.0        0.0
# 2      2      AFG      Asia  Afghanistan  26-02-2020          5.0        0.0
# 3      3      AFG      Asia  Afghanistan  27-02-2020          5.0        0.0
# 4      4      AFG      Asia  Afghanistan  28-02-2020          5.0        0.0
#
#    population new_cases_smoothed total_deaths  ...  \
# 0  39835428.0               None         None  ...
# 1  39835428.0               None         None  ...
# 2  39835428.0               None         None  ...
# 3  39835428.0               None         None  ...
# 4  39835428.0               None         None  ...
#
#   new_deaths_smoothed_per_million reproduction_rate  icu_patients  \
# 0                            None              None          None
# ...

# %%
sql= '''
select *
from covid_vac
limit 5'''
df1.sql= pd.read_sql_query(sql,con)
df1.sql
# Out:
#    index iso_code continent     location        date total_tests  \
# 0      0      AFG      Asia  Afghanistan  24-02-2020        None
# 1      1      AFG      Asia  Afghanistan  25-02-2020        None
# 2      2      AFG      Asia  Afghanistan  26-02-2020        None
# 3      3      AFG      Asia  Afghanistan  27-02-2020        None
# 4      4      AFG      Asia  Afghanistan  28-02-2020        None
#
#   total_tests_per_thousand new_tests_per_thousand new_tests_smoothed  \
# 0                     None                   None               None
# 1                     None                   None               None
# 2                     None                   None               None
# 3                     None                   None               None
# 4                     None                   None               None
#
#   new_tests_smoothed_per_thousand  ... female_smokers male_smokers  \
# 0                            None  ...           None         None
# ...

# %%
sql = '''
Select location,date,total_cases,total_deaths,(total_deaths/total_cases)*100 as DeathPercent
from covid_deaths
where location = 'india'
limit 50
 '''

df1.sql= pd.read_sql_query(sql,con) ## first case and likelihood of contracting.gettimg indioa specific but otherts also
df1.sql
# Out:
#    location        date  total_cases  total_deaths  DeathPercent
# 0     India  30-01-2020          1.0           NaN           NaN
# 1     India  31-01-2020          1.0           NaN           NaN
# 2     India  01-02-2020          1.0           NaN           NaN
# 3     India  02-02-2020          2.0           NaN           NaN
# 4     India  03-02-2020          3.0           NaN           NaN
# 5     India  04-02-2020          3.0           NaN           NaN
# 6     India  05-02-2020          3.0           NaN           NaN
# 7     India  06-02-2020          3.0           NaN           NaN
# 8     India  07-02-2020          3.0           NaN           NaN
# 9     India  08-02-2020          3.0           NaN           NaN
# 10    India  09-02-2020          3.0           NaN           NaN
# 11    India  10-02-2020          3.0           NaN           NaN
# 12    India  11-02-2020          3.0           NaN           NaN
# ...

# %%
## looking total cases vs population 

sql='''Select location,date,total_cases,population,(total_cases/population)*100 as CasePercent
from covid_deaths
where location  = 'india'
'''

df1.sql= pd.read_sql_query(sql,con)
df1.sql
# Out:
#     location        date  total_cases    population   CasePercent
# 0      India  30-01-2020          1.0  1.393409e+09  7.176644e-08
# 1      India  31-01-2020          1.0  1.393409e+09  7.176644e-08
# 2      India  01-02-2020          1.0  1.393409e+09  7.176644e-08
# 3      India  02-02-2020          2.0  1.393409e+09  1.435329e-07
# 4      India  03-02-2020          3.0  1.393409e+09  2.152993e-07
# ..       ...         ...          ...           ...           ...
# 667    India  27-11-2021   34572523.0  1.393409e+09  2.481147e+00
# 668    India  28-11-2021   34580832.0  1.393409e+09  2.481743e+00
# 669    India  29-11-2021   34587822.0  1.393409e+09  2.482245e+00
# 670    India  30-11-2021   34596776.0  1.393409e+09  2.482887e+00
# 671    India  01-12-2021   34606541.0  1.393409e+09  2.483588e+00
#
# [672 rows x 5 columns]

# %%
## highest infection rate

sql='''Select location,population,max(total_cases)as highestInfection,max((total_cases/population))*100 as PercentPoulationinfected
from covid_deaths
group by location,population
order by Percentpoulationinfected desc
limit 51
'''

df1.sql= pd.read_sql_query(sql,con)
df1.sql
# Out:
#            location    population  highestInfection  PercentPoulationinfected
# 0        Montenegro  6.280510e+05          157611.0                 25.095255
# 1        Seychelles  9.891000e+04           23537.0                 23.796381
# 2           Andorra  7.735400e+04           17426.0                 22.527600
# 3          Slovakia  5.460726e+06         1182562.0                 21.655765
# 4           Georgia  3.979773e+06          850102.0                 21.360565
# 5          Slovenia  2.078723e+06          423162.0                 20.356825
# 6           Czechia  1.072455e+07         2172084.0                 20.253376
# 7            Serbia  6.871547e+06         1257025.0                 18.293188
# 8        San Marino  3.401000e+04            6084.0                 17.888856
# 9         Lithuania  2.689862e+06          472239.0                 17.556254
# 10         Maldives  5.436200e+05           91750.0                 16.877598
# ...

# %%
# highest deaths by country,continent is not null
sql='''Select location,max(total_deaths) as highestDeath 
from covid_deaths
where continent is not null
group by location,population
order by highestDeath  desc
limit 20
'''

df1.sql= pd.read_sql_query(sql,con)
df1.sql
# Out:
#           location  highestDeath
# 0    United States      782100.0
# 1           Brazil      614964.0
# 2            India      469724.0
# 3           Mexico      294428.0
# 4           Russia      271091.0
# 5             Peru      201176.0
# 6   United Kingdom      145586.0
# 7        Indonesia      143840.0
# 8            Italy      133931.0
# 9             Iran      129912.0
# 10        Colombia      128586.0
# 11          France      120208.0
# 12       Argentina      116597.0
# 13         Germany      102183.0
# 14         Ukraine       91860.0
# 15    South Africa       89871.0
# 16           Spain       88080.0
# 17          Poland       84153.0
# 18          Turkey       77038.0
# 19         Romania       56618.0

# %%
## highest death   by continent
sql='''Select continent,max(total_deaths) as Deathcount 
from covid_deaths
where continent is not null
group by continent
order by Deathcount desc

'''

df1.sql= pd.read_sql_query(sql,con)
df1.sql
# Out:
#        continent  Deathcount
# 0  North America    782100.0
# 1  South America    614964.0
# 2           Asia    469724.0
# 3         Europe    271091.0
# 4         Africa     89871.0
# 5        Oceania      2021.0

# %%
# new cases and deaths everyday globally 
sql='''
select date, sum(new_cases) as Daily_cases, sum(total_deaths) as Daily_deaths,
from covid_deaths
where continent is not null
group by date
order by 2
limit 50
'''
df1.sql= pd.read_sql_query(sql,con)
df1.sql
# Out:
#           date  Daily_cases  Daily_deaths
# 0   19-01-2020          NaN           NaN
# 1   20-01-2020          NaN           NaN
# 2   21-01-2020          NaN           NaN
# 3   22-01-2020          NaN          17.0
# 4   18-01-2020          NaN           NaN
# 5   09-01-2020          NaN           NaN
# 6   10-01-2020          NaN           NaN
# 7   07-01-2020          NaN           NaN
# 8   12-01-2020          NaN           NaN
# 9   06-01-2020          NaN           NaN
# 10  13-01-2020          NaN           NaN
# 11  14-01-2020          NaN           NaN
# 12  15-01-2020          NaN           NaN
# 13  16-01-2020          NaN           NaN
# 14  08-01-2020          NaN           NaN
# 15  05-01-2020          NaN           NaN
# 16  17-01-2020          NaN           NaN
# 17  04-01-2020          NaN           NaN
# 18  03-01-2020          NaN           NaN
# 19  02-01-2020          NaN           NaN
# 20  01-01-2020          NaN           NaN
# ...

# %%
# % death all over world
sql='''
select  sum(total_cases) as Daily_cases, sum(total_deaths) as Daily_deaths,  (sum(total_deaths)/sum(total_cases))*100
as WorldDeathPercent
from covid_deaths
where continent is not null

limit 50
'''
df1.sql= pd.read_sql_query(sql,con)
df1.sql
# Out:
#     Daily_cases  Daily_deaths  WorldDeathPercent
# 0  6.651606e+10  1.480813e+09           2.226249

# %%
## looking at total population vs vaccinated we will join two tables
sql= '''
select *
from covid_deaths cd 
join covid_vac cv
on cd.location = cv.location 
and cd.date= cv.date'''

df1.sql= pd.read_sql_query(sql,con)
df1.sql.head()
# Out:
#    index iso_code continent     location        date  total_cases  new_cases  \
# 0      0      AFG      Asia  Afghanistan  24-02-2020          5.0        5.0
# 1      1      AFG      Asia  Afghanistan  25-02-2020          5.0        0.0
# 2      2      AFG      Asia  Afghanistan  26-02-2020          5.0        0.0
# 3      3      AFG      Asia  Afghanistan  27-02-2020          5.0        0.0
# 4      4      AFG      Asia  Afghanistan  28-02-2020          5.0        0.0
#
#    population  new_cases_smoothed  total_deaths  ...  female_smokers  \
# 0  39835428.0                 NaN           NaN  ...             NaN
# 1  39835428.0                 NaN           NaN  ...             NaN
# 2  39835428.0                 NaN           NaN  ...             NaN
# 3  39835428.0                 NaN           NaN  ...             NaN
# 4  39835428.0                 NaN           NaN  ...             NaN
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
sql = '''
select cd.continent,cd.location,cd.date,cd.population,cv.new_vaccinations
from covid_deaths cd 
join covid_vac cv
on cd.location = cv.location 
and cd.date= cv.date
where cd.continent is not null
order  by 2
limit 50'''

df1.sql= pd.read_sql_query(sql,con)
df1.sql.head()
# Out:
#   continent     location        date  population new_vaccinations
# 0      Asia  Afghanistan  24-02-2020  39835428.0             None
# 1      Asia  Afghanistan  25-02-2020  39835428.0             None
# 2      Asia  Afghanistan  26-02-2020  39835428.0             None
# 3      Asia  Afghanistan  27-02-2020  39835428.0             None
# 4      Asia  Afghanistan  28-02-2020  39835428.0             None

# %%
## rolling count of vaccination
sql = '''
select cd.continent,cd.location,cd.date,cd.population,cv.new_vaccinations,
sum(cv.new_vaccinations) over(partition by cd.location order by cd.location,cd.date ) as Rolling_count_vacc
from covid_deaths cd 
join covid_vac cv
on cd.location = cv.location 
and cd.date= cv.date
where cd.continent is not null and cd.location = 'india'
order  by 2 
'''

df1.sql= pd.read_sql_query(sql,con)
df1.sql.tail(20)
# Out:
#     continent location        date    population  new_vaccinations  \
# 652      Asia    India  30-09-2020  1.393409e+09               NaN
# 653      Asia    India  30-09-2021  1.393409e+09         6732827.0
# 654      Asia    India  30-10-2020  1.393409e+09               NaN
# 655      Asia    India  30-10-2021  1.393409e+09         6780798.0
# 656      Asia    India  30-11-2020  1.393409e+09               NaN
# 657      Asia    India  30-11-2021  1.393409e+09         8563136.0
# 658      Asia    India  30-12-2020  1.393409e+09               NaN
# 659      Asia    India  31-01-2020  1.393409e+09               NaN
# 660      Asia    India  31-01-2021  1.393409e+09           14509.0
# 661      Asia    India  31-03-2020  1.393409e+09               NaN
# 662      Asia    India  31-03-2021  1.393409e+09         2063543.0
# 663      Asia    India  31-05-2020  1.393409e+09               NaN
# 664      Asia    India  31-05-2021  1.393409e+09         1784772.0
# ...

# %%
## %  population vs vaccination per date for india

sql= '''
with cte as(select cd.continent,cd.location,cd.date,cd.population,cv.new_vaccinations,
sum(cv.new_vaccinations) over(partition by cd.location order by cd.location,cd.date ) as Rolling_count_vacc
from covid_deaths cd 
join covid_vac cv
on cd.location = cv.location 
and cd.date= cv.date
where cd.continent is not null 
order  by 2) 

select continent,location,date,population, (Rolling_count_vacc/population)*100 as People_vaccinated_perct
from cte
where location ='india'
'''
df1.sql= pd.read_sql_query(sql,con)
df1.sql.tail(50)
# Out:
#     continent location        date    population  People_vaccinated_perct
# 622      Asia    India  29-04-2021  1.393409e+09                77.311254
# 623      Asia    India  29-05-2020  1.393409e+09                77.311254
# 624      Asia    India  29-05-2021  1.393409e+09                77.592733
# 625      Asia    India  29-06-2020  1.393409e+09                77.592733
# 626      Asia    India  29-06-2021  1.393409e+09                78.023356
# 627      Asia    India  29-07-2020  1.393409e+09                78.023356
# 628      Asia    India  29-07-2021  1.393409e+09                78.405691
# 629      Asia    India  29-08-2020  1.393409e+09                78.405691
# 630      Asia    India  29-08-2021  1.393409e+09                78.888183
# 631      Asia    India  29-09-2020  1.393409e+09                78.888183
# 632      Asia    India  29-09-2021  1.393409e+09                79.350919
# 633      Asia    India  29-10-2020  1.393409e+09                79.350919
# ...
