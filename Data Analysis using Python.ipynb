# %%
## importing the libraries for analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## importing the Data from local Directory using Pandas

# %%
Data= pd.read_csv('C:\\Users\\vishal rana\\Downloads\\Weather.csv')

# %%
Data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
## Analysing the data and getting an overview of Data (shape,index,columns,datatypes,unique,)

# %%
Data.head(5)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
Data.tail(5)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8779            9.7     100.13    Snow
# 8780            9.7     100.03    Snow
# 8781            4.8      99.95    Snow
# 8782            9.7      99.91    Snow
# 8783           11.3      99.89    Snow

# %%
Data.shape
# Out:
# (8784, 8)

# %%
Data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
Data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
Data.dtypes ## We observe that Date/time is object datatype whereas it should be Datetime
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
Data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
Data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
Data.count() ## Here we observe that we get 8784 records returned fro each attribute. This shows we don't have any null values.
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
Data['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
Data.describe() ## We Gain  direct insight into the crux of the dataset including mean,average standard deviation and much more.
                ##It also relects upon the outliers for each attribute and will come very handy while working with it.
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
## Now we start exploring the data
## 1. Chrecking null values

# %%
Data.isnull()
# Out:
#       Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0         False   False             False      False            False
# 1         False   False             False      False            False
# 2         False   False             False      False            False
# 3         False   False             False      False            False
# 4         False   False             False      False            False
# ...         ...     ...               ...        ...              ...
# 8779      False   False             False      False            False
# 8780      False   False             False      False            False
# 8781      False   False             False      False            False
# 8782      False   False             False      False            False
# 8783      False   False             False      False            False
#
#       Visibility_km  Press_kPa  Weather
# 0             False      False    False
# 1             False      False    False
# ...

# %%
Data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# Here we reconfirm that our Dataset dosen't conatin ant null values.

# %%
## 2. Corroborating the mean of wind speed and check for outliers

# %%
Data['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
Data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
Data['Wind Speed_km/h'].value_counts().sort_index(ascending=True)
# Out:
# 0     309
# 2       2
# 4     474
# 6     609
# 7     677
# 9     830
# 11    791
# 13    735
# 15    719
# 17    666
# 19    616
# 20    496
# 22    439
# 24    374
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 43     13
# 44     14
# 46     11
# 48     13
# 50      4
# 52      7
# 54      1
# 57      5
# 63      1
# 70      1
# 83      1
# Name: Wind Speed_km/h, dtype: int64

# %% [markdown]
# As we earlier observed that Mean of wind speed  14.945469 km/h, using value_count function we check the validity and also for if outliers exist.
# Result- We found that most values for wind speed lie between wind speed range of 0-30km/h. Thus Validating the Mean Value of wind speed. Also observed outliers but as criteria of wind speed specified, it could be ignored.

# %%
## 3.Finding values for Weather when Clear

# %%
Data.Weather.value_counts().get("Clear")
# Out:
# 1326

# %%
Data[Data.Weather =='Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# Here we find the count first for Clear Weather = 1326, and then using the value we get the table with Values of Clear weather.

# %%
Data[Data.Weather.str.contains('Snow')]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5         57               22
# 44      1/2/2012 20:00    -5.6             -13.4         54               24
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# 47      1/2/2012 23:00    -7.4             -14.1         59               17
# 48       1/3/2012 0:00    -9.0             -16.0         57               28
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
 Data[(Data['Wind Speed_km/h']> 24) & (Data['Visibility_km'] == 25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %%
## Minimum and Maximum value of each value of each column against each Weather Condition and comparing the to

# %%
Minimum=Data.groupby("Weather").min()

# %%
Minimum
# Out:
#                                                 Date/Time  Temp_C  \
# Weather
# Clear                                      1/11/2012 1:00   -23.3
# Cloudy                                     1/1/2012 17:00   -21.4
# Drizzle                                   1/23/2012 21:00     1.1
# Drizzle,Fog                               1/23/2012 20:00     0.0
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     0.3
# Fog                                         1/1/2012 0:00   -16.0
# Freezing Drizzle                          1/13/2012 10:00    -9.0
# Freezing Drizzle,Fog                        1/1/2012 2:00    -6.4
# Freezing Drizzle,Haze                      2/1/2012 11:00    -5.8
# Freezing Drizzle,Snow                      1/13/2012 3:00    -8.3
# Freezing Fog                               1/22/2012 6:00   -19.0
# ...

# %%
## Max value of each value of each column against each Weather Condition

# %%
Maximum=Data.groupby("Weather").max()

# %%
Maximum
# Out:
#                                                 Date/Time  Temp_C  \
# Weather
# Clear                                       9/9/2012 5:00    32.8
# Cloudy                                     9/9/2012 23:00    30.5
# Drizzle                                    9/30/2012 3:00    18.8
# Drizzle,Fog                                9/30/2012 2:00    19.9
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/19/2012 18:00     1.2
# Drizzle,Snow,Fog                          12/22/2012 3:00     1.1
# Fog                                        9/22/2012 0:00    20.8
# Freezing Drizzle                            2/1/2012 5:00    -2.3
# Freezing Drizzle,Fog                      12/10/2012 5:00    -0.3
# Freezing Drizzle,Haze                      2/1/2012 13:00    -5.0
# Freezing Drizzle,Snow                      3/2/2012 12:00    -3.3
# Freezing Fog                               3/17/2012 6:00    -0.1
# ...

# %%
Data[(Data['Weather']== 'Clear' )& (Data['Rel Hum_%'] > 50) | (Data.Visibility_km >40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
## Converting the datatype of Data/time from Object to datetime datatype and fetching it for a specific date.

# %%
Data['Date/Time']=pd.to_datetime(Data['Date/Time'])

# %%
Data[Data['Date/Time'] == '2012-01-06'].get('Press_kPa')
# Out:
# 120    100.81
# Name: Press_kPa, dtype: float64

# %%
## Top 10 temperature

# %%
Data['Temp_C'].sort_values(ascending=False).head(10)
# Out:
# 4695    33.0
# 4143    33.0
# 4696    32.9
# 5199    32.8
# 4694    32.7
# 4142    32.6
# 5201    32.5
# 5200    32.5
# 4697    32.5
# 4144    32.5
# Name: Temp_C, dtype: float64

# %%
## Getting Months extracted from datatime into another column named Month

# %%
Data['Month'] = Data['Date/Time'].dt.month_name(locale='English')

# %%
Data
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa               Weather  \
# 0                   4            8.0     101.24                   Fog
# 1                   4            8.0     101.24                   Fog
# ...

# %%
## Now using the graphs to analyse the data.
## 1. we compare Temperature in each month and wind speed.

# %%
plt.rcParams["figure.figsize"] = [10,5]
Data.plot(x='Month',y='Temp_C'),
Data.plot(x='Month',y='Wind Speed_km/h');

# %% [markdown]
# We find that for January month Wind speed is  the highest and also temperature is the lowest reaching Beyond -20C. whereas for the months of june to september, temperature is high due to less speed of Wind.
# Here we can infer that Temperature and Wind are inversely related to each other.

# %%
## we try to find relation between weather and wind speed

# %%
Data.plot(x='Weather',y='Wind Speed_km/h')
# Out:
# <AxesSubplot:xlabel='Weather'>

# %% [markdown]
# As we can see from the plot wind has a consisyent range of 15-25 km/h for each Weather. Also some outliers can be seen but don't convey much about the data.

# %%
## now we see compare relative humidity for Weather

# %%
Data.plot(x='Weather',y='Rel Hum_%');

# %%
Thus We can found Various inferences based on the Analsyis using Python.
